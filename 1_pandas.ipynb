# %% [markdown]
# <a href="https://colab.research.google.com/github/SyedHasnat/Explore-Python-Libraries/blob/main/1_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Library

# %% [markdown]
# ## How to import Library?

# %%
import pandas as pd #as pd means that i will use pd with dot operation to call the functions of this specfic library

# %% [markdown]
# ## Now read a file

# %%
data = pd.read_csv('E:\\0_PYTHON\\9_Datasets\\Time_Series_Datasets\\daily-minimum-temperatures.csv')

# %% [markdown]
# ## Now display the read data

# %%
data.head()
# Out:
#        Date  Temp
# 0  1/1/1981  20.7
# 1  1/2/1981  17.9
# 2  1/3/1981  18.8
# 3  1/4/1981  14.6
# 4  1/5/1981  15.8

# %% [markdown]
# ## No, I want to display the whole Dataset

# %%
data
# Out:
#             Date  Temp
# 0       1/1/1981  20.7
# 1       1/2/1981  17.9
# 2       1/3/1981  18.8
# 3       1/4/1981  14.6
# 4       1/5/1981  15.8
# 5       1/6/1981  15.8
# 6       1/7/1981  15.8
# 7       1/8/1981  17.4
# 8       1/9/1981  21.8
# 9      1/10/1981  20.0
# 10     1/11/1981  16.2
# 11     1/12/1981  13.3
# 12     1/13/1981  16.7
# 13     1/14/1981  21.5
# 14     1/15/1981  25.0
# 15     1/16/1981  20.7
# 16     1/17/1981  20.6
# 17     1/18/1981  24.8
# 18     1/19/1981  17.7
# 19     1/20/1981  15.5
# 20     1/21/1981  18.2
# 21     1/22/1981  12.1
# 22     1/23/1981  14.4
# 23     1/24/1981  16.0
# 24     1/25/1981  16.5
# 25     1/26/1981  18.7
# 26     1/27/1981  19.4
# 27     1/28/1981  17.2
# 28     1/29/1981  15.5
# 29     1/30/1981  15.1
# 30     1/31/1981  15.4
# 31      2/1/1981  15.3
# 32      2/2/1981  18.8
# 33      2/3/1981  21.9
# 34      2/4/1981  19.9
# 35      2/5/1981  16.6
# 36      2/6/1981  16.8
# 37      2/7/1981  14.6
# 38      2/8/1981  17.1
# 39      2/9/1981  25.0
# 40     2/10/1981  15.0
# 41     2/11/1981  13.7
# 42     2/12/1981  13.9
# 43     2/13/1981  18.3
# 44     2/14/1981  22.0
# 45     2/15/1981  22.1
# 46     2/16/1981  21.2
# 47     2/17/1981  18.4
# 48     2/18/1981  16.6
# 49     2/19/1981  16.1
# ...          ...   ...
# 3600  11/12/1990  12.6
# 3601  11/13/1990  13.8
# 3602  11/14/1990  14.6
# 3603  11/15/1990  13.2
# 3604  11/16/1990  12.3
# 3605  11/17/1990   8.8
# 3606  11/18/1990  10.7
# 3607  11/19/1990   9.9
# 3608  11/20/1990   8.3
# 3609  11/21/1990  15.0
# 3610  11/22/1990  12.2
# 3611  11/23/1990  10.5
# 3612  11/24/1990  11.1
# 3613  11/25/1990  13.0
# 3614  11/26/1990  12.9
# 3615  11/27/1990   8.8
# 3616  11/28/1990  14.7
# 3617  11/29/1990  14.7
# 3618  11/30/1990  12.7
# 3619   12/1/1990  13.3
# 3620   12/2/1990  13.2
# 3621   12/3/1990  16.2
# 3622   12/4/1990  17.3
# 3623   12/5/1990  20.5
# 3624   12/6/1990  20.2
# 3625   12/7/1990  19.4
# 3626   12/8/1990  15.5
# 3627   12/9/1990  14.1
# 3628  12/10/1990  11.0
# 3629  12/11/1990  11.1
# 3630  12/12/1990  14.0
# 3631  12/13/1990  11.4
# 3632  12/14/1990  12.5
# 3633  12/15/1990  13.4
# 3634  12/16/1990  13.6
# 3635  12/17/1990  13.9
# 3636  12/18/1990  17.2
# 3637  12/19/1990  14.7
# 3638  12/20/1990  15.4
# 3639  12/21/1990  13.1
# 3640  12/22/1990  13.2
# 3641  12/23/1990  13.9
# 3642  12/24/1990  10.0
# 3643  12/25/1990  12.9
# 3644  12/26/1990  14.6
# 3645  12/27/1990  14.0
# 3646  12/28/1990  13.6
# 3647  12/29/1990  13.5
# 3648  12/30/1990  15.7
# 3649  12/31/1990  13.0
#
# [3650 rows x 2 columns]

# %% [markdown]
# ## To find maximum Temprature in a given column

# %%
data["Temp"].max() #Temp is the column name in dsataset
# Out:
# 26.3

# %% [markdown]
# ## How to find coressponding date for 26.3?

# %%
coressponding_date_for_ = data.loc[data["Temp"] == 26.3, "Date"]
coressponding_date_for_
#you can also display like temp>12 etc
# Out:
# 410    2/15/1982
# Name: Date, dtype: object

# %% [markdown]
# ## Pandas offers count, mean, std, min, 25%, 50%, 75%, max etc

# %% [markdown]
# ## I’m interested in rows 20 till 25 and columns 1 to 2

# %%
data.iloc[20: 26, 0: 2] #i thnk zero cloumn paki dy da serial number wala column count ki
# Out:
#          Date  Temp
# 20  1/21/1981  18.2
# 21  1/22/1981  12.1
# 22  1/23/1981  14.4
# 23  1/24/1981  16.0
# 24  1/25/1981  16.5
# 25  1/26/1981  18.7

# %% [markdown]
# ## If you have used pd.head( ) and you want to know about the rows and cloumns

# %%
data.shape
# Out:
# (3650, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3650 entries, 0 to 3649
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3650 non-null   object
#  1   Temp    3650 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 57.2+ KB

# %% [markdown]
# ## I want to display specifice number of columns

# %%
pd.set_option('display.max_columns', 1)
pd.set_option('display.expand_frame_repr', True)

# %%
data1 = pd.read_csv('E:\\0_PYTHON\\9_Datasets\\Time_Series_Datasets\\daily-minimum-temperatures.csv')

# %%
data1
# Out:
#             Date  ...
# 0       1/1/1981  ...
# 1       1/2/1981  ...
# 2       1/3/1981  ...
# 3       1/4/1981  ...
# 4       1/5/1981  ...
# 5       1/6/1981  ...
# 6       1/7/1981  ...
# 7       1/8/1981  ...
# 8       1/9/1981  ...
# 9      1/10/1981  ...
# 10     1/11/1981  ...
# 11     1/12/1981  ...
# 12     1/13/1981  ...
# 13     1/14/1981  ...
# 14     1/15/1981  ...
# 15     1/16/1981  ...
# 16     1/17/1981  ...
# 17     1/18/1981  ...
# 18     1/19/1981  ...
# 19     1/20/1981  ...
# 20     1/21/1981  ...
# 21     1/22/1981  ...
# 22     1/23/1981  ...
# 23     1/24/1981  ...
# 24     1/25/1981  ...
# 25     1/26/1981  ...
# 26     1/27/1981  ...
# 27     1/28/1981  ...
# 28     1/29/1981  ...
# 29     1/30/1981  ...
# 30     1/31/1981  ...
# 31      2/1/1981  ...
# 32      2/2/1981  ...
# 33      2/3/1981  ...
# 34      2/4/1981  ...
# 35      2/5/1981  ...
# 36      2/6/1981  ...
# 37      2/7/1981  ...
# 38      2/8/1981  ...
# 39      2/9/1981  ...
# 40     2/10/1981  ...
# 41     2/11/1981  ...
# 42     2/12/1981  ...
# 43     2/13/1981  ...
# 44     2/14/1981  ...
# 45     2/15/1981  ...
# 46     2/16/1981  ...
# 47     2/17/1981  ...
# 48     2/18/1981  ...
# 49     2/19/1981  ...
# ...          ...  ...
# 3600  11/12/1990  ...
# 3601  11/13/1990  ...
# 3602  11/14/1990  ...
# 3603  11/15/1990  ...
# 3604  11/16/1990  ...
# 3605  11/17/1990  ...
# 3606  11/18/1990  ...
# 3607  11/19/1990  ...
# 3608  11/20/1990  ...
# 3609  11/21/1990  ...
# 3610  11/22/1990  ...
# 3611  11/23/1990  ...
# 3612  11/24/1990  ...
# 3613  11/25/1990  ...
# 3614  11/26/1990  ...
# 3615  11/27/1990  ...
# 3616  11/28/1990  ...
# 3617  11/29/1990  ...
# 3618  11/30/1990  ...
# 3619   12/1/1990  ...
# 3620   12/2/1990  ...
# 3621   12/3/1990  ...
# 3622   12/4/1990  ...
# 3623   12/5/1990  ...
# 3624   12/6/1990  ...
# 3625   12/7/1990  ...
# 3626   12/8/1990  ...
# 3627   12/9/1990  ...
# 3628  12/10/1990  ...
# 3629  12/11/1990  ...
# 3630  12/12/1990  ...
# 3631  12/13/1990  ...
# 3632  12/14/1990  ...
# 3633  12/15/1990  ...
# 3634  12/16/1990  ...
# 3635  12/17/1990  ...
# 3636  12/18/1990  ...
# 3637  12/19/1990  ...
# 3638  12/20/1990  ...
# 3639  12/21/1990  ...
# 3640  12/22/1990  ...
# 3641  12/23/1990  ...
# 3642  12/24/1990  ...
# 3643  12/25/1990  ...
# 3644  12/26/1990  ...
# 3645  12/27/1990  ...
# 3646  12/28/1990  ...
# 3647  12/29/1990  ...
# 3648  12/30/1990  ...
# 3649  12/31/1990  ...
#
# [3650 rows x 2 columns]

# %% [markdown]
# ## By default head( ) function displays first 5 entries

# %%
#first i will change number os columns to display
pd.set_option('display.max_columns',2)
data.head(10) #10 means to display first 10 entries
# Out:
#         Date  Temp
# 0   1/1/1981  20.7
# 1   1/2/1981  17.9
# 2   1/3/1981  18.8
# 3   1/4/1981  14.6
# 4   1/5/1981  15.8
# 5   1/6/1981  15.8
# 6   1/7/1981  15.8
# 7   1/8/1981  17.4
# 8   1/9/1981  21.8
# 9  1/10/1981  20.0

# %%
data.tail()
# Out:
#             Date  Temp
# 3645  12/27/1990  14.0
# 3646  12/28/1990  13.6
# 3647  12/29/1990  13.5
# 3648  12/30/1990  15.7
# 3649  12/31/1990  13.0

# %%
data.tail(10)
# Out:
#             Date  Temp
# 3640  12/22/1990  13.2
# 3641  12/23/1990  13.9
# 3642  12/24/1990  10.0
# 3643  12/25/1990  12.9
# 3644  12/26/1990  14.6
# 3645  12/27/1990  14.0
# 3646  12/28/1990  13.6
# 3647  12/29/1990  13.5
# 3648  12/30/1990  15.7
# 3649  12/31/1990  13.0

# %% [markdown]
# ## Now I want to access each colimn separately

# %%
date = data['Date'] #note: chi pa data set ki yi da column pa start ki sa likali v srf agha ba pass k
d_50 = date.head(50)

# %%
temp = data['Temp']
t_50 = temp.head(50)
#t_t=[t_50]
#print(t_t)
#t_50

# %% [markdown]
# ## Now I want to plot this data (temp with date) dy date ya time ta pa time series ki mong index wayo

# %%
#first import matplotlib
import matplotlib.pyplot as plt # or from matplotlib import pyplot as plt

# %%
plt.plot(d_50,t_50,color='k',linestyle='--',marker='o',label='temprature')
plt.xlabel('date')
plt.ylabel('remprature')
plt.title('daily-minimum-temperatures')
plt.legend()
plt.show()

# %% [markdown]
# ## Another way to plot data set

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Very Interesting to give a tabuler formate to data

# %%
my_data = pd.DataFrame({"S.No":['1','2','3','4','5'],"Name":['Syed','Muhammad','Hasnat','Ali','Tirmize'],"Gender":['Male','Male','Male','Male','Male']})

# %%
my_data
# Out:
#   S.No      Name Gender
# 0    1      Syed   Male
# 1    2  Muhammad   Male
# 2    3    Hasnat   Male
# 3    4       Ali   Male
# 4    5   Tirmize   Male

# %% [markdown]
# ## Now I want to export this data to a csv file

# %% [markdown]
# ### Neither you can use filehandling approch like .write(my_data) because my_data is not a string it's dataframe nor we have a built-in function like int2str( ).......How to handle this lets focus on below code

# %%
dataframe = pd.DataFrame({"S.No":['1','2','3','4','5'],"Name":['Syed','Muhammad','Hasnat','Ali','Tirmize'],"Gender":['Male','Male','Male','Male','Male']})

# %%
import os
#create csv file
my_file = open('from_dataframe_to_csv.csv','x') 
#export dataframe to csv file 
dataframe.to_csv('from_dataframe_to_csv.csv', index=False)
#read csv file
dataa = pd.read_csv('from_dataframe_to_csv.csv')
#display .csv file data
dataa
# Out:
#    S.No      Name Gender
# 0     1      Syed   Male
# 1     2  Muhammad   Male
# 2     3    Hasnat   Male
# 3     4       Ali   Male
# 4     5   Tirmize   Male

# %% [markdown]
# ## Lets plot another dataset

# %%
import pandas as pd
import matplotlib. pyplot as plt
air_quality = pd. read_csv("E:\\0_PYTHON\\9_Datasets\\air_quality_no2.csv", index_col=0, parse_dates=True)
air_quality.head(6)
# Out:
#                      station_antwerp  ...  station_london
# datetime                              ...
# 2019-05-07 02:00:00              NaN  ...            23.0
# 2019-05-07 03:00:00             50.5  ...            19.0
# 2019-05-07 04:00:00             45.0  ...            19.0
# 2019-05-07 05:00:00              NaN  ...            16.0
# 2019-05-07 06:00:00              NaN  ...             NaN
# 2019-05-07 07:00:00              NaN  ...            26.0
#
# [6 rows x 3 columns]

# %% [markdown]
# ## Line Plot

# %%
air_quality. plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# ## Subplot

# %%
axs = air_quality.plot.area(figsize=(16,8),subplots=True) #figsize=(L,W)
